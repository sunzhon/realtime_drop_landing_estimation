# %%
import sys
import os
sys.path.append("./../")


from assessment.scores import *
from assessment.visualization import *
from vicon_imu_data_process.process_rawdata import *
import time

# %% [markdown]
# ## Generate metrics files of the testing_results_folders.txt

# %%
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/1_imu/1_imu_125_175/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/1_imu/1_imu_25_lstm/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/2_imu/2_imu_25_lstm/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/2_imu/2_imu_75/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/3_imu/3_imu_25_lstm_units/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/3_imu/3_imu_75/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/3_imu/3_imu_125_175/testing_result_folders.txt"
P5_results
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/4_imu/4_5_imu_125/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/4_imu/4_imu_25_lstm_units/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/4_imu/4_imu_75/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/4_imu/4_imu_175/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/5_imu/5_imu_25/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/5_imu/5_imu_75/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/5_imu/5_imu_125/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/5_imu/5_imu_175/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/6_7_8_imu/6_7_8_imu_25_lstm/testing_result_folders.txt"
#combination_investigation_results = RESULTS_PATH+"P5_results/4_collected_sensor_lstm/6_7_8_imu/75_125_175/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"/optimal_config_of_four_cases/4_imu_single-leg/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"/optimal_config_of_four_cases/8_imu_single-leg/testing_result_folders.txt"
combination_investigation_results = RESULTS_PATH+"/optimal_config_of_four_cases/4_imu_single-leg/testing_result_folders.txt"
#combination_investigation_results = RESULTS_PATH+"P5_results/Four_variable_optimal_imu_config/KEM_single_leg/testing_result_folders.txt"

#combination_investigation_results = RESULTS_PATH+"/P5_results/Four_variable_optimal_imu_config/KEM_single_leg/testing_result_folders.txt"
#combination_investigation_results = RESULTS_PATH+"/P5_results/Four_variable_optimal_imu_config/vGRF_single_leg/testing_result_folders.txt"
#combination_investigation_results = RESULTS_PATH+"/P5_results/Four_variable_optimal_imu_config/vGRF_double_legs/testing_result_folders.txt"
#combination_investigation_results = RESULTS_PATH+"/P5_results/Four_variable_optimal_imu_config/KEM_double_legs/testing_result_folders.txt"

metrics = get_list_investigation_metrics(combination_investigation_results)

# %% [markdown]
# ## [*Paper* Table.1] List statistical metrics of vGRF and KEM during single- and double-leg drop landings
#
# There are four folders with their metrics.csv files which contains the four taraget variables: vGRF and KEM of single- and double-leg drop landings.

# %%
list_combination_investigation_results = [
   # RESULT_FOLDER+"/Four_variable_optimal_imu_config/vGRF_single_leg/metrics.csv",
   # RESULT_FOLDER+"/Four_variable_optimal_imu_config/KEM_single_leg/metrics.csv",
   RESULT_FOLDER+"/Four_variable_optimal_imu_config/vGRF_double_legs/metrics.csv",
   # RESULT_FOLDER+"/Four_variable_optimal_imu_config/KEM_double_legs/metrics.csv"
    ]
metric_fields=['r2','rmse','r_rmse']
#metrics = get_list_investigation_metrics(list_combination_investigation_results,metric_fields=metric_fields)

metrics = parase_list_investigation_metrics(list_combination_investigation_results, 
                                            landing_manner='double_legs', 
                                            estimated_variable='all', 
                                            syn_features_label='both', 
                                            use_frame_index='both', 
                                            LSTM_unit='all',
                                            sensor_config='all',
                                            IMU_number='all', 
                                            drop_value=0.4, 
                                            metric_fields=['r2','rmse','r_rmse'],
                                            sort_variable=None)

displayed_metrics = metrics[['scores','landing_manners','estimated_variables','Sensor configurations','metrics','Metrics ID']]
displayed_metrics.groupby(['estimated_variables','landing_manners','Sensor configurations','metrics']).describe().round(2)
# Out:
# /media/sun/DATA1/drop_landing_workspace/results/training_testing/P5_results/Four_variable_optimal_imu_config/vGRF_double_legs/metrics.csv
# DROP R2 cases below :0.4
# /home/sun/.pyenv/versions/DataVisualization/lib/python3.9/site-packages/pandas/core/indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /home/sun/.pyenv/versions/DataVisualization/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ## [*Paper* Table.1 in revised manuscript] List statistical metrics of vGRF and KEM during single- and double-leg drop landings
#
# There are four folders with their metrics.csv files which contains the four target variables: vGRF and KEM of single- and double-leg drop landings.
#
# In the revised manuscript, it is also to indicates the lowest results with their IMU configuration.

# %%
list_combination_investigation_results = [
    RESULT_FOLDER+"/Four_variable_optimal_imu_config/vGRF_single_leg/metrics.csv",
   # RESULT_FOLDER+"/Four_variable_optimal_imu_config/KEM_single_leg/metrics.csv",
   # RESULT_FOLDER+"/Four_variable_optimal_imu_config/vGRF_double_legs/metrics.csv",
   # RESULT_FOLDER+"/Four_variable_optimal_imu_config/KEM_double_legs/metrics.csv"
    ]

#t1 = RESULT_FOLDER+"/4_collected_sensor_lstm/metrics.csv"
#t2 = RESULT_FOLDER+"/4_collected_sensor_lstm/6_7_8_imu/6_7_8_imu_all_lstm/metrics.csv"
#t3 = [
#    RESULT_FOLDER+"/4_collected_sensor_lstm/1_imu/1_imu_125_175/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/1_imu/1_imu_25_lstm/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/2_imu/2_imu_25_lstm/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/2_imu/2_imu_75/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/3_imu/3_imu_25_lstm_units/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/3_imu/3_imu_75/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/3_imu/3_imu_125_175/metrics.csv",
#
#    RESULT_FOLDER+"/4_collected_sensor_lstm/4_imu/4_5_imu_125/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/4_imu/4_imu_25_lstm_units/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/4_imu/4_imu_75/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/4_imu/4_imu_175/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/5_imu/5_imu_25/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/5_imu/5_imu_75/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/5_imu/5_imu_125/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/5_imu/5_imu_175/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/6_7_8_imu/6_7_8_imu_25_lstm/metrics.csv",
#    RESULT_FOLDER+"/4_collected_sensor_lstm/6_7_8_imu/75_125_175/metrics.csv"
#]
#list_combination_investigation_results += [t1, t2] +t3

metrics = parase_list_investigation_metrics(list_combination_investigation_results, 
                                            landing_manner='double_legs', 
                                            estimated_variable='all', 
                                            syn_features_label='both', 
                                            use_frame_index='both', 
                                            LSTM_unit=[130],
                                            sensor_config='all',
                                            IMU_number='all', 
                                            drop_value=0.4, 
                                            metric_fields=['r2','rmse','r_rmse'],
                                            #metric_fields=['r2'],
                                            sort_variable=None)

displayed_metrics = metrics[['scores','landing_manners','estimated_variables','Sensor configurations','metrics']]
xx = displayed_metrics.groupby(['estimated_variables','landing_manners','Sensor configurations','metrics']).describe().round(2)
# Out:
# /media/sun/DATA1/drop_landing_workspace/results/training_testing/P5_results/Four_variable_optimal_imu_config/vGRF_single_leg/metrics.csv
# DROP R2 cases below :0.4
# specified landing manner is wrong for the /media/sun/DATA1/drop_landing_workspace/results/training_testing/P5_results/Four_variable_optimal_imu_config/vGRF_single_leg/metrics.csv
# ALl estimated variables are used
# All sensor configurations are used
# All IMU number are used
# /home/sun/.pyenv/versions/DataVisualization/lib/python3.9/site-packages/pandas/core/indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /home/sun/.pyenv/versions/DataVisualization/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# ...

# %%
yy=xx['scores']['mean'].reset_index(3)
print(yy[yy['metrics']=='r2']['mean'].idxmin())
xx
# Out:
# ('GRF', 'single_leg', 'FSTC')
#                                                                   scores  \
#                                                                    count
# estimated_variables landing_manners Sensor configurations metrics
# GRF                 single_leg      FSTC                  r2        99.0
#                                                           r_rmse    99.0
#                                                           rmse      99.0
#                                     FSTW                  r2       100.0
#                                                           r_rmse   100.0
#                                                           rmse     100.0
#                                     FSTWC                 r2       100.0
#                                                           r_rmse   100.0
#                                                           rmse     100.0
# ...

# %%
# Out:
#                                                                   scores  \
#                                                                    count
# estimated_variables landing_manners Sensor configurations metrics
# GRF                 single_leg      FSTC                  r2        99.0
#                                                           r_rmse    99.0
#                                                           rmse      99.0
#                                     FSTW                  r2       100.0
#                                                           r_rmse   100.0
#                                                           rmse     100.0
#                                     FSTWC                 r2       100.0
#                                                           r_rmse   100.0
#                                                           rmse     100.0
#                                     FSTWCF                r2       300.0
# ...
